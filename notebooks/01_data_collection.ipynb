# %%
# Cell 1 — Imports
import yfinance as yf
import pandas as pd

# %%
# Cell 2 — Download SPY data
spy = yf.download("SPY", start="2015-01-01", end="2025-12-31", auto_adjust=True)
print(spy.shape)
print(spy.head())

# %%
# Cell 3 — Inspect
print(spy.dtypes)
print(spy.isnull().sum())

# %%
# Cell 4 — Save to CSV
spy.to_csv("../data/spy_raw.csv")
print("Saved successfully")
